# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as pllt
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D,MaxPooling2D,Flatten,Dense

# %%
(x_train,y_train),(x_test,y_test)=fashion_mnist.load_data()

# %%
model= Sequential()
model.add(Conv2D(64,(3,3),input_shape=(28,28,1)))
model.add(MaxPooling2D((2,2)))
model.add(Flatten())
model.add(Dense(128,activation="relu"))
model.add(Dense(10,activation="softmax"))

# %%
model.compile(optimizer="adam",loss="sparse_categorical_crossentropy")
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 64)        640
#
#  max_pooling2d (MaxPooling2  (None, 13, 13, 64)        0
#  D)
#
#  flatten (Flatten)           (None, 10816)             0
#
#  dense (Dense)               (None, 128)               1384576
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 1386506 (5.29 MB)
# Trainable params: 1386506 (5.29 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.fit(x_train,y_train,epochs=10,validation_split=0.2)
# Out:
# Epoch 1/10
# 1500/1500 [==============================] - 46s 30ms/step - loss: 1.6236 - val_loss: 0.5188
# Epoch 2/10
# 1500/1500 [==============================] - 44s 29ms/step - loss: 0.4162 - val_loss: 0.4372
# Epoch 3/10
# 1500/1500 [==============================] - 44s 30ms/step - loss: 0.3695 - val_loss: 0.4216
# Epoch 4/10
# 1500/1500 [==============================] - 44s 29ms/step - loss: 1.0189 - val_loss: 0.7735
# Epoch 5/10
# 1500/1500 [==============================] - 44s 29ms/step - loss: 0.5351 - val_loss: 0.4996
# Epoch 6/10
# 1500/1500 [==============================] - 44s 29ms/step - loss: 0.4704 - val_loss: 0.5369
# Epoch 7/10
# 1500/1500 [==============================] - 44s 29ms/step - loss: 0.4521 - val_loss: 0.3798
# Epoch 8/10
# 1500/1500 [==============================] - 44s 29ms/step - loss: 0.5992 - val_loss: 0.3780
# Epoch 9/10
# 1500/1500 [==============================] - 44s 29ms/step - loss: 0.4718 - val_loss: 0.4890
# Epoch 10/10
# 1500/1500 [==============================] - 44s 29ms/step - loss: 0.3658 - val_loss: 0.4548

# %%
pred=model.predict(x_test[:1])
pred
# Out:
# 1/1 [==============================] - 0s 153ms/step
# array([[1.4647218e-29, 8.2115577e-21, 0.0000000e+00, 3.4377370e-13,
#         0.0000000e+00, 1.4540912e-03, 9.1223859e-24, 1.8425584e-04,
#         5.4480483e-12, 9.9836165e-01]], dtype=float32)

# %%
pllt.imsow(x_test[0].reshape(28,28),cmap="gray")
pllt.title("Predicted Label")
pllt.axis("off")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-d7201b361fa3> in <module>
# ----> 1 plt.imsow(x_test[0].reshape(28,28),cmap="gray")
#       2 plt.title("Predicted Label")
#       3 plt.axis("off")
#       4 plt.show()
#
# NameError: name 'plt' is not defined
